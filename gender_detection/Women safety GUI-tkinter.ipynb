# %%
import tkinter as tk
from tkinter import ttk

# Create the main window
root = tk.Tk()
root.title("Women Safety Analytics Platform")
root.geometry("1200x800")  # Set window size

# Header Section
header_frame = tk.Frame(root, bg="lightblue", height=50)
header_frame.pack(side="top", fill="x")

header_label = tk.Label(header_frame, text="Women Safety Analytics Platform", font=("Arial", 24), bg="lightblue")
header_label.pack(pady=10)

# Sidebar with Links to Different Pages
sidebar_frame = tk.Frame(root, bg="lightgray", width=200)
sidebar_frame.pack(side="left", fill="y")

def navigate_to(page_name):
    # Clear the content frame
    for widget in content_frame.winfo_children():
        widget.destroy()

    # Load the selected page
    if page_name == "Historical Data":
        historical_data_page()
    elif page_name == "Hotspot Areas":
        hotspot_areas_page()
    elif page_name == "Camera Locations":
        camera_locations_page()

sidebar_buttons = ["Historical Data", "Hotspot Areas", "Camera Locations"]
for button_text in sidebar_buttons:
    btn = tk.Button(sidebar_frame, text=button_text, font=("Arial", 14), bg="white", command=lambda bt=button_text: navigate_to(bt))
    btn.pack(pady=10, fill="x")

# Main Content Frame
content_frame = tk.Frame(root, bg="white")
content_frame.pack(side="right", fill="both", expand=True)

def historical_data_page():
    historical_data_label = tk.Label(content_frame, text="Historical Data", font=("Arial", 20), bg="white")
    historical_data_label.pack(pady=20)

    # Add charts, graphs, and historical data visualization here

def hotspot_areas_page():
    hotspot_areas_label = tk.Label(content_frame, text="Hotspot Areas", font=("Arial", 20), bg="white")
    hotspot_areas_label.pack(pady=20)

    # Add hotspot maps, tables, etc. here

def camera_locations_page():
    camera_locations_label = tk.Label(content_frame, text="Camera Locations", font=("Arial", 20), bg="white")
    camera_locations_label.pack(pady=20)

    # Add camera location details and links here

# Set the initial content to Historical Data
navigate_to("Historical Data")

# Report Section
report_frame = tk.Frame(root, bg="lightyellow", height=150)
report_frame.pack(side="bottom", fill="x")

report_label = tk.Label(report_frame, text="Report Section", font=("Arial", 18), bg="lightyellow")
report_label.pack(pady=10)

# Start the main loop
root.mainloop()
